# %%
from stock_bot.TradingSystem import *
from stock_bot.AlpacaDataManager import *
from stock_bot.Indicators import *
from stock_bot.Strategy import *
from stock_bot.TA_LIB_FunctionMapping import *
from pathlib import Path
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
api_keys = './config/api_keys.yaml'
strategy  = "./config/stage-based-trading-system.yaml"


with open(api_keys, 'r') as file:
    keys = yaml.safe_load(file)

with open(strategy, 'r') as file:
    yaml_trade_config = yaml.safe_load(file)


strategy = Strategy(yaml_trade_config, keys)

# %%
strategy.config
# Out:
# {'symbols': ['PLTR',
#   'SOFI',
#   'IONQ',
#   'VRT',
#   'QQQ',
#   'SPY',
#   'AAPL',
#   'TSLA',
#   'AMZN',
#   'GOOGL'],
#  'timeframe': '1m',
#  'start_date': '2024-01-01',
#  'end_date': '2024-12-31',
#  'entry_conditions': [{'indicator': 'close',
#    'comparison': 'above',
#    'value': 'sma_20'},
#   {'indicator': 'ema_5', 'comparison': 'crosses_above', 'value': 'sma_20'}],
#  'exit_conditions': [{'indicator': 'close',
#    'comparison': 'below',
#    'value': 'ema_20'},
#   {'indicator': 'ema_5', 'comparison': 'crosses_below', 'value': 'ema_20'},
#   {'indicator': 'close', 'comparison': 'below', 'value': 'lowerband'}],
#  'risk_management': {'position_sizing_method': 'risk_based',
#   'risk_per_trade': 0.1,
#   'stop_loss': 0.02,
#   'take_profit': 0.06,
#   'max_position_size': 1000.0,
#   'atr_multiplier': 2.0},
#  'indicators': [{'name': 'EMA', 'params': {'period': 5}},
#   {'name': 'EMA', 'params': {'period': 20}},
#   {'name': 'SMA', 'params': {'period': 20}},
# ...

# %%
strategy = Strategy(yaml_trade_config, keys)
strategy.get_data()  # Load and prepare data
# View trade history
# Out:
# Getting data for these symbols:  ['PLTR', 'SOFI', 'IONQ', 'VRT', 'QQQ', 'SPY', 'AAPL', 'TSLA', 'AMZN', 'GOOGL']
#   symbol                 timestamp   open   high    low  close   volume  \
# 0   PLTR 2024-01-02 08:53:00+00:00  17.46  17.46  17.21  17.33  29837.0
# 1   PLTR 2024-01-02 09:04:00+00:00  17.33  17.33  17.27  17.28   9630.0
# 2   PLTR 2024-01-02 09:15:00+00:00  17.26  17.27  17.25  17.27  10839.0
# 3   PLTR 2024-01-02 09:26:00+00:00  17.27  17.30  17.26  17.30   2580.0
# 4   PLTR 2024-01-02 09:37:00+00:00  17.29  17.31  17.27  17.31  16999.0
#
#    trade_count       vwap   ema_5  ...  close_prev  ema_5_prev  ema_20_prev  \
# 0        206.0  17.344132     NaN  ...         NaN         NaN          NaN
# 1        142.0  17.285152     NaN  ...       17.33         NaN          NaN
# 2        117.0  17.261493     NaN  ...       17.28         NaN          NaN
# 3         36.0  17.288342     NaN  ...       17.27         NaN          NaN
# ...

# %%
strategy.df
# Out:
#       symbol                 timestamp    open      high     low     close  \
# 0       PLTR 2024-01-02 08:53:00+00:00   17.46   17.4600   17.21   17.3300
# 1       PLTR 2024-01-02 09:04:00+00:00   17.33   17.3300   17.27   17.2800
# 2       PLTR 2024-01-02 09:15:00+00:00   17.26   17.2700   17.25   17.2700
# 3       PLTR 2024-01-02 09:26:00+00:00   17.27   17.3000   17.26   17.3000
# 4       PLTR 2024-01-02 09:37:00+00:00   17.29   17.3100   17.27   17.3100
# ...      ...                       ...     ...       ...     ...       ...
# 99995  GOOGL 2024-06-21 20:54:00+00:00  179.63  180.0600  179.63  180.0400
# 99996  GOOGL 2024-06-21 21:05:00+00:00  179.97  180.0748  179.94  179.9994
# 99997  GOOGL 2024-06-21 21:16:00+00:00  179.98  179.9900  179.95  179.9600
# 99998  GOOGL 2024-06-21 21:27:00+00:00  180.00  180.0800  180.00  180.0800
# 99999  GOOGL 2024-06-21 21:38:00+00:00  180.18  180.1800  179.63  179.6300
#
# ...

# %%
def plot_equity_with_trades(equity_curve, trades_df):
    plt.figure(figsize=(15, 8))
    
    # Plot equity curve
    equity_curve.plot()
    
    # Add buy markers (entries)
    plt.scatter(trades_df['entry_date'], 
               trades_df['account_balance'], 
               marker='^', 
               color='green', 
               s=100, 
               label='Buy')
    
    # Add sell markers (exits)
    plt.scatter(trades_df['exit_date'], 
               trades_df['account_balance'], 
               marker='v', 
               color='red', 
               s=100, 
               label='Sell')
    
    plt.title('Equity Curve with Trade Markers')
    plt.xlabel('Date')
    plt.ylabel('Account Balance ($)')
    plt.legend()
    plt.grid(True)
    
    # Rotate x-axis dates for better readability
    plt.xticks(rotation=45)
    
    plt.tight_layout()
    plt.show()

# %%
trades

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def plot_interactive_trades(equity_curve, trades_df):
    # Create the figure
    fig = make_subplots(rows=1, cols=1)
    
    # Add equity curve
    fig.add_trace(
        go.Scatter(
            x=equity_curve.index,
            y=equity_curve,
            name='Equity Curve',
            line=dict(color='blue', width=1),
            hovertemplate='<b>Date</b>: %{x}<br>' +
                         '<b>Balance</b>: $%{y:,.2f}<br>'
        )
    )
    
    # Add buy markers
    fig.add_trace(
        go.Scatter(
            x=trades_df['entry_date'],
            y=trades_df['account_balance'],
            mode='markers+text',
            name='Buy',
            marker=dict(symbol='triangle-up', size=12, color='green'),
            text=trades_df['symbol'],
            textposition='top center',
            hovertemplate='<b>Symbol</b>: %{text}<br>' +
                         '<b>Entry Date</b>: %{x}<br>' +
                         '<b>Entry Price</b>: $%{customdata[0]:,.2f}<br>' +
                         '<b>Account Balance</b>: $%{y:,.2f}<br>' +
                         '<b>Position Size</b>: %{customdata[1]:,.0f}<br>',
            customdata=list(zip(trades_df['entry_price'], 
                              trades_df['position_size']))
        )
    )
    
    # Add sell markers
    fig.add_trace(
        go.Scatter(
            x=trades_df['exit_date'],
            y=trades_df['account_balance'],
            mode='markers+text',
            name='Sell',
            marker=dict(symbol='triangle-down', size=12, color='red'),
            text=trades_df['symbol'],
            textposition='bottom center',
            hovertemplate='<b>Symbol</b>: %{text}<br>' +
                         '<b>Exit Date</b>: %{x}<br>' +
                         '<b>Exit Price</b>: $%{customdata[0]:,.2f}<br>' +
                         '<b>Account Balance</b>: $%{y:,.2f}<br>' +
                         '<b>P&L</b>: $%{customdata[1]:,.2f}<br>',
            customdata=list(zip(trades_df['exit_price'], 
                              trades_df['pnl']))
        )
    )
    
    # Update layout
    fig.update_layout(
        title='Interactive Trading Performance Visualization',
        xaxis_title='Date',
        yaxis_title='Account Balance ($)',
        hovermode='closest',
        showlegend=True,
        height=800,
        template='plotly_white',
        # Add range slider
        xaxis=dict(
            rangeslider=dict(visible=True),
            type='date'
        ),
        # Add dropdown for time ranges
        updatemenus=[{
            'buttons': [
                {'args': [{'xaxis.range': ['1m']}],
                 'label': '1m',
                 'method': 'relayout'},
                {'args': [{'xaxis.range': ['6m']}],
                 'label': '6m',
                 'method': 'relayout'},
                {'args': [{'xaxis.range': ['ytd']}],
                 'label': 'YTD',
                 'method': 'relayout'},
                {'args': [{'xaxis.range': ['1y']}],
                 'label': '1y',
                 'method': 'relayout'},
                {'args': [{'xaxis.range': [None, None]}],
                 'label': 'All',
                 'method': 'relayout'}
            ],
            'direction': 'right',
            'showactive': True,
            'type': 'buttons',
            'x': 0.7,
            'y': 1.2
        }]
    )
    
    return fig

# Usage:
# fig = plot_interactive_trades(strategy.equity, trades_df)
# fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def plot_interactive_trades(equity_curve, trades_df):
    # Create the figure
    fig = make_subplots(rows=1, cols=1)
    
    # Add equity curve
    fig.add_trace(
        go.Scatter(
            x=equity_curve.index,
            y=equity_curve,
            name='Equity Curve',
            line=dict(color='blue', width=1),
            hovertemplate='<b>Date</b>: %{x}<br>' +
                         '<b>Balance</b>: $%{y:,.2f}<br>'
        )
    )
    
    # Add buy markers
    fig.add_trace(
        go.Scatter(
            x=trades_df['entry_date'],
            y=trades_df['account_balance'],
            mode='markers+text',
            name='Buy',
            marker=dict(symbol='triangle-up', size=12, color='green'),
            text=trades_df['symbol'],
            textposition='top center',
            hovertemplate='<b>Symbol</b>: %{text}<br>' +
                         '<b>Entry Date</b>: %{x}<br>' +
                         '<b>Entry Price</b>: $%{customdata[0]:,.2f}<br>' +
                         '<b>Account Balance</b>: $%{y:,.2f}<br>' +
                         '<b>Position Size</b>: %{customdata[1]:,.0f}<br>',
            customdata=list(zip(trades_df['entry_price'], 
                              trades_df['position_size']))
        )
    )
    
    # Add sell markers
    fig.add_trace(
        go.Scatter(
            x=trades_df['exit_date'],
            y=trades_df['account_balance'],
            mode='markers+text',
            name='Sell',
            marker=dict(symbol='triangle-down', size=12, color='red'),
            text=trades_df['symbol'],
            textposition='bottom center',
            hovertemplate='<b>Symbol</b>: %{text}<br>' +
                         '<b>Exit Date</b>: %{x}<br>' +
                         '<b>Exit Price</b>: $%{customdata[0]:,.2f}<br>' +
                         '<b>Account Balance</b>: $%{y:,.2f}<br>' +
                         '<b>P&L</b>: $%{customdata[1]:,.2f}<br>',
            customdata=list(zip(trades_df['exit_price'], 
                              trades_df['pnl']))
        )
    )
    
    # Update layout
    fig.update_layout(
        title='Interactive Trading Performance Visualization',
        xaxis_title='Date',
        yaxis_title='Account Balance ($)',
        hovermode='closest',
        showlegend=True,
        height=800,
        template='plotly_white',
        xaxis=dict(
            type='date'
        )
    )
    
    return fig

# Usage:
# fig = plot_interactive_trades(strategy.equity, trades_df)
# fig.show()

# %%
# Usage:
fig = plot_interactive_trades(equity, trades)
fig.show()

# %%
trades.pnl.sum()

# %%
from stock_bot.AlpacaStrategy import AlpacaPaperStrategy

# %%
strategy = AlpacaPaperStrategy(yaml_trade_config, keys)

# %%
# Check if market is open
if not strategy.check_market_hours():
    strategy.wait_for_market_open()

# Run the strategy with 1-minute intervals
strategy.run_paper_trading(interval_seconds=60)
# Out:
# Starting paper trading strategy...
# Getting data for these symbols:  ['PLTR', 'SOFI', 'IONQ', 'VRT', 'QQQ', 'SPY', 'AAPL', 'TSLA', 'AMZN', 'GOOGL']
#   symbol                 timestamp     open   high      low  close   volume  \
# 0   PLTR 2024-12-19 00:05:00+00:00  72.5005  72.55  72.2300  72.23  48428.0
# 1   PLTR 2024-12-19 00:16:00+00:00  72.1843  72.25  72.0000  72.15  73688.0
# 2   PLTR 2024-12-19 00:27:00+00:00  72.2000  72.53  72.1500  72.53  46950.0
# 3   PLTR 2024-12-19 00:38:00+00:00  72.5000  72.50  72.2500  72.29  28378.0
# 4   PLTR 2024-12-19 00:49:00+00:00  72.3000  72.40  72.2555  72.39  56561.0
#
#    trade_count       vwap   ema_5  ...  close_prev  ema_5_prev  ema_20_prev  \
# 0        525.0  72.341277     NaN  ...         NaN         NaN          NaN
# 1        580.0  72.118734     NaN  ...       72.23         NaN          NaN
# 2        467.0  72.407424     NaN  ...       72.15         NaN          NaN
# ...

# %%
strategy.get_current_market_data()
# Out:
# Getting data for these symbols:  ['PLTR', 'SOFI', 'IONQ', 'VRT', 'QQQ', 'SPY', 'AAPL', 'TSLA', 'AMZN', 'GOOGL']
#   symbol                 timestamp     open   high      low   close   volume  \
# 0   PLTR 2024-12-18 00:04:00+00:00  73.3700  73.42  73.2000  73.310  41629.0
# 1   PLTR 2024-12-18 00:15:00+00:00  73.3201  73.45  73.3000  73.420  22541.0
# 2   PLTR 2024-12-18 00:26:00+00:00  73.4500  73.45  73.2500  73.390  33432.0
# 3   PLTR 2024-12-18 00:37:00+00:00  73.2801  73.45  73.2801  73.330  23421.0
# 4   PLTR 2024-12-18 00:48:00+00:00  73.3300  73.33  73.1900  73.216  50637.0
#
#    trade_count       vwap    ema_5  ...  close_prev  ema_5_prev  ema_20_prev  \
# 0        356.0  73.329724      NaN  ...         NaN         NaN          NaN
# 1        258.0  73.336508      NaN  ...       73.31         NaN          NaN
# 2        372.0  73.336802      NaN  ...       73.42         NaN          NaN
# 3        246.0  73.352693      NaN  ...       73.39         NaN          NaN
# ...
